# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Leo los csv 
r1_df=pd.read_csv('infowork/AccesosaInternetfijoportecnologiaylocalidad_2791751682205468463.csv')
r2_df=pd.read_csv('infowork/AccesosaInternetfijoporvelocidadbajadayprovincia_2791741682206075895.csv')
r3_df=pd.read_csv('infowork/AccesosaInternetfijoporvelocidaddebajadaylocalidad_2776171682206065243.csv')
r4_df=pd.read_csv('infowork/API_NY.GDP.PCAP.CD_DS2_es_csv_v2_5359609.csv')
r5_df=pd.read_csv('infowork/ConectividadalserviciodeInternet_2776151682205479736.csv')
r6_df=pd.read_excel('infowork/EPH_tot_urbano_estructura_bases_2022.xls')
r7_df=pd.read_csv('infowork/historico_velocidad_internet.csv')
r10_df=pd.read_csv('infowork/Internet_Accesos-por-velocidad (1).csv')
r11_df=pd.read_csv('infowork/Internet_Accesos-por-velocidad.csv')
r12_df=pd.read_csv('infowork/Internet_BAF (1).csv')
r13_df=pd.read_csv('infowork/Internet_BAF.csv')
r14_df=pd.read_csv('infowork/Internet_Ingresos.csv')
r15_df=pd.read_csv('infowork/Internet_Penetracion (1).csv')
r16_df=pd.read_csv('infowork/Internet_Penetracion (2).csv')
r17_df=pd.read_csv('infowork/Internet_Penetracion.csv')
r18_df=pd.read_csv('infowork/Listadodelocalidadesconconectividadainternet_2750221682205474397.csv')
r19_df=pd.read_csv('infowork/Metadata_Country_API_NY.GDP.PCAP.CD_DS2_es_csv_v2_5359609.csv')
r20_df=pd.read_csv('infowork/Metadata_Indicator_API_NY.GDP.PCAP.CD_DS2_es_csv_v2_5359609.csv')

# %%
r1_df.head()
# Out:
#       Provincia     Partido               Localidad Link Indec ADSL
# 0  BUENOS AIRES  25 de Mayo              25 de Mayo    6854100  873  \
# 1  BUENOS AIRES  25 de Mayo               Del Valle    6854020  181
# 2  BUENOS AIRES  25 de Mayo       Gobernador Ugarte    6854040  - 0
# 3  BUENOS AIRES  25 de Mayo  Norberto de la Riestra    6854060  - 0
# 4  BUENOS AIRES  25 de Mayo        Lucas Monteverde    6854050  - 0
#
#   CABLEMODEM DIAL UP FIBRA OPTICA OTROS SATELITAL WIMAX WIRELESS
# 0      4.704     - 0            2   - 0       975   - 0      664  \
# 1        - 0     - 0          - 0    10         1   - 0      - 0
# 2        - 0     - 0          - 0   - 0       - 0   - 0      181
# 3        782     - 0            6   167       - 0   - 0      327
# 4        - 0     - 0          - 0   - 0       - 0   - 0        6
#
#   Total general  Unnamed: 13
# 0         7.218          NaN
# 1           192          NaN
# 2           181          NaN
# 3         1.282          NaN
# ...

# %%
r1_df.info()
r1_df.isnull().sum()
r1_df= r1_df.drop("Unnamed: 13", axis=1)
#r1_df=r1_df.rename(columns={"Partido":"Fecha"})
r1_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3142 entries, 0 to 3141
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Provincia      3142 non-null   object
#  1   Partido        3142 non-null   object
#  2   Localidad      3142 non-null   object
#  3   Link Indec     3142 non-null   object
#  4   ADSL           3142 non-null   object
#  5   CABLEMODEM     3142 non-null   object
#  6   DIAL UP        3142 non-null   object
#  7   FIBRA OPTICA   3142 non-null   object
#  8   OTROS          3142 non-null   object
#  9   SATELITAL      3142 non-null   object
#  10  WIMAX          3142 non-null   object
#  11  WIRELESS       3142 non-null   object
#  12  Total general  3142 non-null   object
#  13  Unnamed: 13    0 non-null      float64
# dtypes: float64(1), object(13)
# memory usage: 343.8+ KB
#          Provincia      Partido                           Localidad
# ...

# %%
r1_df.to_csv('datasets/acceso_internetfijo_tecloc.csv', index=False)

# %%
r2_df
r2_df.dropna(inplace=True)
r2_df.info()
r2_df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 480 entries, 0 to 479
# Data columns (total 97 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Año         480 non-null    float64
#  1   Trimestre   480 non-null    float64
#  2   Provincia   480 non-null    object
#  3   Otros       480 non-null    object
#  4   0,256 Mbps  480 non-null    object
#  5   0,375 Mbps  480 non-null    object
#  6   0,625 Mbps  480 non-null    object
#  7   0,5 Mbps    480 non-null    object
#  8   0,512 Mbps  480 non-null    object
#  9   0,75 Mbps   480 non-null    object
#  10  1 Mbps      480 non-null    object
#  11  1,2 Mbps    480 non-null    object
#  12  1,25 Mbps   480 non-null    object
#  13  1,5 Mbps    480 non-null    object
#  14  2 Mbps      480 non-null    object
#  15  2,2 Mbps    480 non-null    object
#  16  2,5 Mbps    480 non-null    object
#  17  6,7 Mbps    480 non-null    object
#  18  3 Mbps      480 non-null    object
# ...

# %%
r2_df.to_csv('datasets/vel_bajadaprovincia.csv', index=False)

# %%
r5_df.head()
# Out:
#       Provincia       Partido     Unnamed: 2  Poblacion ADSL CABLEMODEM
# 0  BUENOS AIRES           NaN  Villa Bordeau        0.0   --        NaN  \
# 1  BUENOS AIRES  Bahía Blanca   Villa Espora        NaN   --         --
# 2           NaN      Balcarce       Balcarce    38376.0  NaN         SI
# 3           NaN      Balcarce      Los Pinos      337.0  NaN         --
# 4           NaN      Balcarce      Napaleofú        NaN  NaN         --
#
#   Unnamed: 6 FIBRAOPTICA SATELITAL WIRELESS TELEFONIAFIJA   3G   4G
# 0        NaN          --        --      NaN           NaN   SI   SI  \
# 1         --         NaN        --       --            --   --  NaN
# 2         SI          SI       NaN       SI            SI  NaN  NaN
# 3         --          --       NaN       SI           NaN   --   --
# 4         --         NaN       NaN       SI            SI   SI   SI
#
#    Unnamed: 13            Latitud           Longitud
# 0          NaN                NaN  -62,3200223419024
# ...

# %%
r7_df.head()
# Out:
#     Año  Trimestre Mbps (Media de bajada)    Trimestre.1
# 0  2022          3                  62,46  Jul-Sept 2022
# 1  2022          2                  58,44   Abr-Jun 2022
# 2  2022          1                  55,11   Ene-Mar 2022
# 3  2021          4                  52,34   Oct-Dic 2021
# 4  2021          3                  48,46  Jul-Sept 2021

# %%
r8_df=pd.read_csv('infowork/historico_velocidad_internet (1).csv')  #Exportamos el df limpio

# %%
r8_df.head()
r8_df.info()
r8_df.isnull().sum()
#r8_df= r8_df.drop("Unnamed: 4", axis=1)  #Borramos columnas de nulos
#r8_df= r8_df.drop("Unnamed: 5", axis=1)  #Borramos columnas de nulos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 840 entries, 0 to 839
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Año                     840 non-null    int64
#  1   Trimestre               840 non-null    int64
#  2   Provincia               840 non-null    object
#  3   Mbps (Media de bajada)  840 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 26.4+ KB
# Año                       0
# Trimestre                 0
# Provincia                 0
# Mbps (Media de bajada)    0
# dtype: int64

# %%
r8_df
# Out:
#       Año  Trimestre            Provincia  Mbps (Media de bajada)
# 0    2022          3         Buenos Aires                      70
# 1    2022          3      Capital Federal                     101
# 2    2022          3            Catamarca                      61
# 3    2022          3                Chaco                      53
# 4    2022          3               Chubut                      16
# ..    ...        ...                  ...                     ...
# 835  2014          1           Santa Cruz                       3
# 836  2014          1             Santa Fe                       3
# 837  2014          1  Santiago Del Estero                       3
# 838  2014          1     Tierra Del Fuego                       3
# 839  2014          1              Tucumán                       3
#
# [840 rows x 4 columns]

# %%
r10_df.head()
r10_df.info()
r10_df['OTROS'] = r10_df['OTROS'].fillna(0) #remplazo por cero los nulos en la columna otros 
r10_df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 840 entries, 0 to 839
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Año                  840 non-null    int64
#  1   Trimestre            840 non-null    int64
#  2   Provincia            840 non-null    object
#  3   HASTA 512 kbps       840 non-null    float64
#  4   + 512 Kbps - 1 Mbps  840 non-null    float64
#  5   + 1 Mbps - 6 Mbps    840 non-null    object
#  6   + 6 Mbps - 10 Mbps   840 non-null    float64
#  7   + 10 Mbps - 20 Mbps  840 non-null    float64
#  8   + 20 Mbps - 30 Mbps  840 non-null    float64
#  9   + 30 Mbps            840 non-null    object
#  10  OTROS                840 non-null    float64
#  11  Total                840 non-null    object
# dtypes: float64(6), int64(2), object(4)
# memory usage: 78.9+ KB
# Año                    0
# Trimestre              0
# Provincia              0
# ...

# %%
r11_df.head()
r11_df.info()
r11_df.isnull().sum()
r11_df= r11_df.drop("Unnamed: 11", axis=1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Año                      35 non-null     int64
#  1   Trimestre                35 non-null     int64
#  2   Hasta 512 kbps           35 non-null     float64
#  3   Entre 512 Kbps y 1 Mbps  35 non-null     float64
#  4   Entre 1 Mbps y 6 Mbps    35 non-null     object
#  5   Entre 6 Mbps y 10 Mbps   35 non-null     object
#  6   Entre 10 Mbps y 20 Mbps  35 non-null     object
#  7   Entre 20 Mbps y 30 Mbps  35 non-null     object
#  8   Más de 30 Mbps           35 non-null     object
#  9   OTROS                    35 non-null     float64
#  10  Total                    35 non-null     object
#  11  Unnamed: 11              0 non-null      float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 3.4+ KB

# %%
r12_df.head()
r12_df.info()
r12_df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Año               35 non-null     int64
#  1   Trimestre         35 non-null     int64
#  2   Banda ancha fija  35 non-null     object
#  3   Dial up           35 non-null     float64
#  4   Total             35 non-null     object
#  5   Periodo           35 non-null     object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 1.8+ KB
# Año                 0
# Trimestre           0
# Banda ancha fija    0
# Dial up             0
# Total               0
# Periodo             0
# dtype: int64

# %%
r12_df.head()
# Out:
#     Año  Trimestre Banda ancha fija  Dial up       Total        Periodo
# 0  2022          3       11.078.691   12.437  11.091.128  Jul-Sept 2022
# 1  2022          2       10.946.248   12.436  10.958.684   Abr-Jun 2022
# 2  2022          1       10.611.390   12.619  10.624.009   Ene-Mar 2022
# 3  2021          4       10.476.933   12.861  10.489.794   Oct-Dic 2021
# 4  2021          3       10.075.184   10.357  10.085.541  Jul-Sept 2021

# %%
r2_df.to_csv('datasets/vel_bajadaprovincia.csv', index=False)

# %%
r13_df.head()
r13_df.info()
r13_df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Año               35 non-null     int64
#  1   Trimestre         35 non-null     int64
#  2   Banda ancha fija  35 non-null     object
#  3   Dial up           35 non-null     float64
#  4   Total             35 non-null     object
#  5   Periodo           35 non-null     object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 1.8+ KB
# Año                 0
# Trimestre           0
# Banda ancha fija    0
# Dial up             0
# Total               0
# Periodo             0
# dtype: int64

# %%
r13_df.head()
# Out:
#     Año  Trimestre Banda ancha fija  Dial up       Total        Periodo
# 0  2022          3       11.078.691   12.437  11.091.128  Jul-Sept 2022
# 1  2022          2       10.946.248   12.436  10.958.684   Abr-Jun 2022
# 2  2022          1       10.611.390   12.619  10.624.009   Ene-Mar 2022
# 3  2021          4       10.476.933   12.861  10.489.794   Oct-Dic 2021
# 4  2021          3       10.075.184   10.357  10.085.541  Jul-Sept 2021

# %%
r2_df.to_csv('datasets/vel_bajadaprovincia.csv', index=False)

# %%
r14_df.head()
r14_df.info()
r14_df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 4 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Año                        35 non-null     int64
#  1   Trimestre                  35 non-null     int64
#  2   Ingresos (miles de pesos)  35 non-null     object
#  3   Periodo                    35 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 1.2+ KB
# Año                          0
# Trimestre                    0
# Ingresos (miles de pesos)    0
# Periodo                      0
# dtype: int64

# %%
r14_df.head()
# Out:
#     Año  Trimestre Ingresos (miles de pesos)        Periodo
# 0  2022          3                67.055.930  Jul-Sept 2022
# 1  2022          2                60.335.724   Abr-Jun 2022
# 2  2022          1                55.589.997   Ene-Mar 2022
# 3  2021          4                45.467.887   Oct-Dic 2021
# 4  2021          3                42.999.944  Jul-Sept 2021

# %%
r14_df.to_csv('datasets/ingresosxtrimestre.csv', index=False)

# %%
r15_df.info()
r15_df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Año                           35 non-null     int64
#  1   Trimestre                     35 non-null     int64
#  2   Accesos por cada 100 hogares  35 non-null     object
#  3   Accesos por cada 100 hab      35 non-null     object
#  4   Periodo                       35 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 1.5+ KB
# Año                             0
# Trimestre                       0
# Accesos por cada 100 hogares    0
# Accesos por cada 100 hab        0
# Periodo                         0
# dtype: int64

# %%
r15_df.head()
# Out:
#     Año  Trimestre Accesos por cada 100 hogares Accesos por cada 100 hab
# 0  2022          3                        76,64                    23,95  \
# 1  2022          2                        75,97                    23,72
# 2  2022          1                        73,88                    23,05
# 3  2021          4                        73,18                    22,81
# 4  2021          3                        70,58                    21,98
#
#          Periodo
# 0  Jul-Sept 2022
# 1   Abr-Jun 2022
# 2   Ene-Mar 2022
# 3   Oct-Dic 2021
# 4  Jul-Sept 2021

# %%
r15_df.to_csv('datasets/pen100hogares_general_hogares_hab.csv', index=False)

# %%
r16_df=pd.read_csv('infowork/Internet_Penetracion (2).csv')

# %%
#r16_df['Accesos por cada 100 hogares'] = r16_df['Accesos por cada 100 hogares'].str.replace(',', '.')
#r16_df['Accesos por cada 100 hogares'] = pd.to_numeric(r16_df['Accesos por cada 100 hogares'], errors='coerce')
r16_df.loc[r16_df['Accesos por cada 100 hogares'] > 100, 'Accesos por cada 100 hogares'] = 100
r16_df.info()
r16_df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 840 entries, 0 to 839
# Data columns (total 4 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Año                           840 non-null    int64
#  1   Trimestre                     840 non-null    int64
#  2   Provincia                     840 non-null    object
#  3   Accesos por cada 100 hogares  840 non-null    float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 26.4+ KB
# Año                             0
# Trimestre                       0
# Provincia                       0
# Accesos por cada 100 hogares    0
# dtype: int64

# %%
#r16_df['Accesos por cada 100 hogares'] =['Accesos por cada 100 hogares'].astype("Int64")
#r16_df['Accesos por cada 100 hogares'] = r16_df['Accesos por cada 100 hogares'].apply(lambda x: 100 if x > 100 else x)
r16_df.head()
# Out:
#     Año  Trimestre        Provincia  Accesos por cada 100 hogares
# 0  2022          3     Buenos Aires                         78.11
# 1  2022          3  Capital Federal                        100.00
# 2  2022          3        Catamarca                         65.33
# 3  2022          3            Chaco                         43.86
# 4  2022          3           Chubut                         84.38

# %%
r16_df.sort_values(by="Accesos por cada 100 hogares")
# Out:
#       Año  Trimestre        Provincia  Accesos por cada 100 hogares
# 834  2014          1         San Luis                          9.35
# 522  2017          2         San Luis                          9.51
# 546  2017          1         San Luis                          9.55
# 642  2016          1         San Luis                          9.59
# 618  2016          2         San Luis                          9.60
# ..    ...        ...              ...                           ...
# 553  2016          4  Capital Federal                        100.00
# 817  2014          1  Capital Federal                        100.00
# 25   2022          2  Capital Federal                        100.00
# 385  2018          3  Capital Federal                        100.00
# 601  2016          2  Capital Federal                        100.00
#
# [840 rows x 4 columns]

# %%
r16_df.to_csv('datasets/pen100hogares_general_hogares_provin.csv', index=False)

# %%
r17_df.info()
r17_df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Año                           35 non-null     int64
#  1   Trimestre                     35 non-null     int64
#  2   Accesos por cada 100 hogares  35 non-null     object
#  3   Accesos por cada 100 hab      35 non-null     object
#  4   Periodo                       35 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 1.5+ KB
# Año                             0
# Trimestre                       0
# Accesos por cada 100 hogares    0
# Accesos por cada 100 hab        0
# Periodo                         0
# dtype: int64

# %%
r17_df.head()
r17_df.sort_values(by="Accesos por cada 100 hab")
# Out:
#      Año  Trimestre Accesos por cada 100 hogares Accesos por cada 100 hab
# 34  2014          1                        49,55                    15,05  \
# 33  2014          2                        49,86                    15,16
# 31  2014          4                         50,5                    15,39
# 32  2014          3                        50,67                    15,43
# 30  2015          1                        51,36                    15,68
# 29  2015          2                        51,76                    15,82
# 26  2016          1                        51,85                     15,9
# 28  2015          3                        52,46                    16,05
# 27  2015          4                        52,63                    16,12
# 25  2016          2                        53,34                    16,37
# 24  2016          3                        53,73                     16,5
# 23  2016          4                        53,94                    16,56
# ...

# %% [markdown]
# Se identifica uyn comportamiento creciente en el acceso a red, teniendo un unico decrecimiento en el año donde se presento la primera oleada de la pandemia del covid 19 (4 trimestre 2019 y 1ro 2020) siendo el crecimiento mas amblio entre los trimestres 1 y 2 de cada año siendo el año ____ donde mayor crecimiento tuvo el acceso
